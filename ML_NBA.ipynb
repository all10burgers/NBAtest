# %%
import time
import pandas as pd
import re
from bs4 import BeautifulSoup

# %%
read_data = pd.read_excel('month_excel/january_2018.xls')
read_data.to_csv("month_csv/january_2018.csv", index=None, header=True)

df = pd.DataFrame(pd.read_csv("month_csv/january_2018.csv"))

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/l2/ypzl1wvs7pxcc5r5vsx4sswm0000gn/T/ipykernel_67380/3246292821.py in <module>
# ----> 1 read_data = pd.read_excel("month_excel/january_2018.xls")
#       2 read_data.to_csv("month_csv/january_2018.csv", index=None, header=True)
#       3
#       4 df = pd.DataFrame(pd.read_csv("month_csv/january_2018.csv"))
#       5
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455     if not isinstance(io, ExcelFile):
#     456         should_close = True
# --> 457         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458     elif engine and engine != io.engine:
#     459         raise ValueError(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1378                 )
#    1379                 if ext is None:
# -> 1380                     raise ValueError(
#    1381                         "Excel file format cannot be determined, you must specify "
#    1382                         "an engine manually."
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.
